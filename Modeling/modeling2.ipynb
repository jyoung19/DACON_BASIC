# %%
from google.colab import drive

drive.mount('/content/drive')
# %cd drive/MyDrive
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import os
import cv2
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("/content/drive/MyDrive/DACON_BASIC/train.csv")
train_df
# Out:
#         id   Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0        1  28.0  Company Invited         1             10.0  Small Business
# 1        2  34.0     Self Enquiry         3              NaN  Small Business
# 2        3  45.0  Company Invited         1              NaN        Salaried
# 3        4  29.0  Company Invited         1              7.0  Small Business
# 4        5  42.0     Self Enquiry         3              6.0        Salaried
# ...    ...   ...              ...       ...              ...             ...
# 1950  1951  28.0     Self Enquiry         1             10.0  Small Business
# 1951  1952  41.0     Self Enquiry         3              8.0        Salaried
# 1952  1953  38.0  Company Invited         3             28.0  Small Business
# 1953  1954  28.0     Self Enquiry         3             30.0  Small Business
# 1954  1955  22.0  Company Invited         1              9.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 0       Male                       3                4.0          Basic
# 1     Female                       2                4.0         Deluxe
# 2       Male                       2                3.0         Deluxe
# 3       Male                       3                5.0          Basic
# 4       Male                       2                3.0         Deluxe
# ...      ...                     ...                ...            ...
# 1950    Male                       3                5.0          Basic
# 1951  Female                       3                3.0   Super Deluxe
# 1952  Female                       3                4.0          Basic
# 1953  Female                       3                5.0         Deluxe
# 1954    Male                       2                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                       3.0       Married            3.0         0
# 1                       4.0        Single            1.0         1
# 2                       4.0       Married            2.0         0
# 3                       4.0       Married            3.0         0
# 4                       3.0      Divorced            2.0         0
# ...                     ...           ...            ...       ...
# 1950                    3.0        Single            2.0         0
# 1951                    5.0      Divorced            1.0         0
# 1952                    3.0      Divorced            7.0         0
# 1953                    3.0       Married            3.0         0
# 1954                    3.0      Divorced            1.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 0                          1       0                       1.0   Executive
# 1                          5       1                       0.0     Manager
# 2                          4       1                       0.0     Manager
# 3                          4       0                       1.0   Executive
# 4                          3       1                       0.0     Manager
# ...                      ...     ...                       ...         ...
# 1950                       1       1                       2.0   Executive
# 1951                       5       1                       1.0         AVP
# 1952                       2       1                       2.0   Executive
# 1953                       1       1                       2.0     Manager
# 1954                       3       0                       0.0   Executive
#
#       MonthlyIncome  ProdTaken
# 0           20384.0          0
# 1           19599.0          1
# 2               NaN          0
# 3           21274.0          1
# 4           19907.0          0
# ...             ...        ...
# 1950        20723.0          0
# 1951        31595.0          0
# 1952        21651.0          0
# 1953        22218.0          0
# 1954        17853.0          1
#
# [1955 rows x 20 columns]

# %%
train_df.shape
# Out:
# (1955, 20)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1955 entries, 0 to 1954
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1955 non-null   int64
#  1   Age                       1861 non-null   float64
#  2   TypeofContact             1945 non-null   object
#  3   CityTier                  1955 non-null   int64
#  4   DurationOfPitch           1853 non-null   float64
#  5   Occupation                1955 non-null   object
#  6   Gender                    1955 non-null   object
#  7   NumberOfPersonVisiting    1955 non-null   int64
#  8   NumberOfFollowups         1942 non-null   float64
#  9   ProductPitched            1955 non-null   object
#  10  PreferredPropertyStar     1945 non-null   float64
#  11  MaritalStatus             1955 non-null   object
#  12  NumberOfTrips             1898 non-null   float64
#  13  Passport                  1955 non-null   int64
#  14  PitchSatisfactionScore    1955 non-null   int64
#  15  OwnCar                    1955 non-null   int64
#  16  NumberOfChildrenVisiting  1928 non-null   float64
#  17  Designation               1955 non-null   object
#  18  MonthlyIncome             1855 non-null   float64
#  19  ProdTaken                 1955 non-null   int64
# dtypes: float64(7), int64(7), object(6)
# memory usage: 305.6+ KB

# %% [markdown]
# - id : 샘플 아이디
# - Age : 나이
# - TypeofContact : 고객의 제품 인지 방법 (회사의 홍보 or 스스로 검색)
# - CityTier : 주거 중인 도시의 등급. (인구, 시설, 생활 수준 기준) (1등급 > 2등급 > 3등급)
# - DurationOfPitch : 영업 사원이 고객에게 제공하는 프레젠테이션 기간
# - Occupation : 직업
# - Gender : 성별
# - NumberOfPersonVisiting : 고객과 함께 여행을 계획 중인 총 인원
# - NumberOfFollowups : 영업 사원의 프레젠테이션 후 이루어진 후속 조치 수
# - ProductPitched : 영업 사원이 제시한 상품
# - PreferredPropertyStar : 선호 호텔 숙박업소 등급
# - MaritalStatus : 결혼여부
# - NumberOfTrips : 평균 연간 여행 횟수
# - Passport : 여권 보유 여부 (0: 없음, 1: 있음)
# - PitchSatisfactionScore : 영업 사원의 프레젠테이션 만족도
# - OwnCar : 자동차 보유 여부 (0: 없음, 1: 있음)
# - NumberOfChildrenVisiting : 함께 여행을 계획 중인 5세 미만의 어린이 수
# - Designation : (직업의) 직급
# - MonthlyIncome : 월 급여
# - ProdTaken : 여행 패키지 신청 여부 (0: 신청 안 함, 1: 신청함)

# %%
train_df['TypeofContact'].value_counts()
# Out:
# Self Enquiry       1379
# Company Invited     566
# Name: TypeofContact, dtype: int64

# %%
train_df['Occupation'].value_counts()
# Out:
# Salaried          965
# Small Business    826
# Large Business    163
# Free Lancer         1
# Name: Occupation, dtype: int64

# %%
train_df['Gender'].value_counts()
# Out:
# Male      1207
# Female     748
# Name: Gender, dtype: int64

# %%
# 'Fe Male'로 저장되어 있는 값들 'Female'로 변경

train_df.loc[train_df['Gender'] == 'Fe Male', 'Gender'] = 'Female'

# %%
train_df['Gender'].value_counts()
# Out:
# Male      1207
# Female     748
# Name: Gender, dtype: int64

# %%
train_df['ProductPitched'].value_counts()
# Out:
# Basic           745
# Deluxe          689
# Standard        302
# Super Deluxe    130
# King             89
# Name: ProductPitched, dtype: int64

# %%
train_df['MaritalStatus'].value_counts()
# Out:
# Married      949
# Divorced     375
# Single       349
# Unmarried    282
# Name: MaritalStatus, dtype: int64

# %%
train_df['Designation'].value_counts()
# Out:
# Executive         745
# Manager           689
# Senior Manager    302
# AVP               130
# VP                 89
# Name: Designation, dtype: int64

# %% [markdown]
# ## 2. 데이터 탐색 (이상치, 결측치 등 확인)

# %% [markdown]
# ### 수치형 변수

# %%
cols = train_df.select_dtypes(exclude=['object']).columns
fig, axes = plt.subplots(2, 7,  figsize=(24,10))
for i, col in enumerate(cols):
    if i <=6:
        k = i
        j  = 0
    else:
        j = 1
        k = i-7
    g = sns.distplot(train_df[train_df['ProdTaken']==0][col], hist=True, kde=False, rug=True, bins=20, label="No"   , ax = axes[j][k])
    h = sns.distplot(train_df[train_df['ProdTaken']==1][col], hist=True, kde=False, rug=True, bins=20, label="Yes", ax = axes[j][k])
    axes[j][k].legend()
    plt.xlabel(col)
plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 여행 패키지 신청한 고객과 신청하지 않은 고객의 분포가 비슷함

# %% [markdown]
# ### 범주형 변수

# %%
train_df.select_dtypes(include=['object']).columns
# Out:
# Index(['TypeofContact', 'Occupation', 'Gender', 'ProductPitched',
#        'MaritalStatus', 'Designation'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 6,  figsize=(24,14))
for i, col in enumerate(['TypeofContact', 'Occupation', 'Gender', 'ProductPitched', 'MaritalStatus', 'Designation']):
    g = sns.countplot(train_df[col] , ax = axes[0][i])
    # axes[i].legend()
    g.set_xticklabels(g.get_xticklabels(), rotation=45,
                  horizontalalignment='right',
                  fontweight='light',
                  fontsize='x-small'
                 )
    plt.xlabel(col)
for i, col in enumerate(['TypeofContact', 'Occupation', 'Gender', 'ProductPitched', 'MaritalStatus', 'Designation']):
    g = sns.countplot(train_df[col],  hue = train_df['ProdTaken'].map({0:'No', 1:'Yes'}) , ax = axes[1][i])
    # axes[i].legend()
    g.set_xticklabels(g.get_xticklabels(), rotation=45,
                  horizontalalignment='right',
                  fontweight='heavy',
                  fontsize='x-large'
                 )
    plt.xlabel(col)


plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### 2-1. 결측치

# %%
train_df.isnull().sum()
# Out:
# id                            0
# Age                          94
# TypeofContact                10
# CityTier                      0
# DurationOfPitch             102
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            13
# ProductPitched                0
# PreferredPropertyStar        10
# MaritalStatus                 0
# NumberOfTrips                57
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     27
# Designation                   0
# MonthlyIncome               100
# ProdTaken                     0
# dtype: int64

# %%
train_df.columns
# Out:
# Index(['id', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome',
#        'ProdTaken'],
#       dtype='object')

# %%
# Age (94개)

print(train_df['Age'].mean())
print(train_df['Age'].median())
# Out:
# 37.46211714132187
# 36.0

# %%
sns.distplot(train_df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 중앙값(36)으로 대체

train_df['Age'] = train_df['Age'].fillna(train_df.Age.median())

# %%
# TypeofContact (10개)

train_df['TypeofContact'].value_counts()
# Out:
# Self Enquiry       1379
# Company Invited     566
# Name: TypeofContact, dtype: int64

# %%
# TypeofContact(범주형)의 결측치(10개)는 삭제

train_df.dropna(subset=['TypeofContact'], inplace=True)

# %%
train_df.isnull().sum()
# Out:
# id                           0
# Age                          0
# TypeofContact                0
# CityTier                     0
# DurationOfPitch             92
# Occupation                   0
# Gender                       0
# NumberOfPersonVisiting       0
# NumberOfFollowups           13
# ProductPitched               0
# PreferredPropertyStar       10
# MaritalStatus                0
# NumberOfTrips               57
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisiting    27
# Designation                  0
# MonthlyIncome               90
# ProdTaken                    0
# dtype: int64

# %%
# DurationOfPitch (102개)

print(train_df['DurationOfPitch'].mean())
print(train_df['DurationOfPitch'].median())
# Out:
# 15.524015110631408
# 14.0

# %%
sns.distplot(train_df['DurationOfPitch'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 중앙값(14)으로 대체

train_df['DurationOfPitch'] = train_df['DurationOfPitch'].fillna(train_df.DurationOfPitch.median())

# %%
# NumberOfFollowups (13개)

print(train_df['NumberOfFollowups'].mean())
print(train_df['NumberOfFollowups'].median())
# Out:
# 3.718331616889804
# 4.0

# %%
sns.distplot(train_df['NumberOfFollowups'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 중앙값(4)으로 대체

train_df['NumberOfFollowups'] = train_df['NumberOfFollowups'].fillna(train_df.NumberOfFollowups.median())

# %%
# PreferredPropertyStar (10개)

print(train_df['PreferredPropertyStar'].mean())
print(train_df['PreferredPropertyStar'].median())
# Out:
# 3.568637532133676
# 3.0

# %%
sns.distplot(train_df['PreferredPropertyStar'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 중앙값(3)으로 대체

train_df['PreferredPropertyStar'] = train_df['PreferredPropertyStar'].fillna(train_df.PreferredPropertyStar.median())

# %%
# NumberOfTrips (57개)

print(train_df['NumberOfTrips'].mean())
print(train_df['NumberOfTrips'].median())
# Out:
# 3.255532139093783
# 3.0

# %%
sns.distplot(train_df['NumberOfTrips'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 중앙값(3)으로 대체

train_df['NumberOfTrips'] = train_df['NumberOfTrips'].fillna(train_df.NumberOfTrips.median())

# %%
# NumberOfChildrenVisiting (27개)

print(train_df['NumberOfChildrenVisiting'].mean())
print(train_df['NumberOfChildrenVisiting'].median())
# Out:
# 1.213174273858921
# 1.0

# %%
sns.distplot(train_df['NumberOfChildrenVisiting'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 중앙값(1)으로 대체

train_df['NumberOfChildrenVisiting'] = train_df['NumberOfChildrenVisiting'].fillna(train_df.NumberOfChildrenVisiting.median())

# %%
# MonthlyIncome (100개)

print(train_df['MonthlyIncome'].mean())
print(train_df['MonthlyIncome'].median())
# Out:
# 23624.108894878707
# 22295.0

# %%
sns.distplot(train_df['MonthlyIncome'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# 평균값(23624.108894878707)으로 대체

train_df['MonthlyIncome'] = train_df['MonthlyIncome'].fillna(train_df.MonthlyIncome.mean())

# %%
train_df.isnull().sum()
# Out:
# id                          0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# ProdTaken                   0
# dtype: int64

# %% [markdown]
# #### 2-2. 이상치

# %%
train_df.dtypes
# Out:
# id                            int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# ProdTaken                     int64
# dtype: object

# %%
def outlier_iqr(data, column): 

    # lower, upper 글로벌 변수 선언하기     
    global lower, upper    
    
    # 4분위수 기준 지정하기     
    q25, q75 = np.quantile(data[column], 0.25), np.quantile(data[column], 0.75)          
    
    # IQR 계산하기     
    iqr = q75 - q25    
    
    # outlier cutoff 계산하기     
    cut_off = iqr * 1.5          
    
    # lower와 upper bound 값 구하기     
    lower, upper = q25 - cut_off, q75 + cut_off     
    
    print('IQR은',iqr, '이다.')     
    print('lower bound 값은', lower, '이다.')     
    print('upper bound 값은', upper, '이다.')    
    
    # 1사 분위와 4사 분위에 속해있는 데이터 각각 저장하기     
    data1 = data[data[column] > upper]     
    data2 = data[data[column] < lower]    
    
    # 이상치 총 개수 구하기
    return print('총 이상치 개수는', data1.shape[0] + data2.shape[0], '이다.')

# %%
train_df.columns
# Out:
# Index(['id', 'Age', 'TypeofContact', 'CityTier', 'DurationOfPitch',
#        'Occupation', 'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome',
#        'ProdTaken'],
#       dtype='object')

# %%
# object 타입 제외 (TypeofContact, Occupation, Gender, ProductPitched, MaritalStatus, Designation)

index = ['id', 'Age', 'CityTier', 'DurationOfPitch', 'NumberOfPersonVisiting', 
         'NumberOfFollowups', 'PreferredPropertyStar', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 
         'OwnCar', 'NumberOfChildrenVisiting', 'MonthlyIncome', 'ProdTaken']

# %%
for i in range(len(index)):
  print('==============================')
  print('%d번째 변수: %s' %(i+1,index[i]))
  outlier_iqr(train_df, index[i])
# Out:
# ==============================
# 1번째 변수: id
# IQR은 974.0 이다.
# lower bound 값은 -970.0 이다.
# upper bound 값은 2926.0 이다.
# 총 이상치 개수는 0 이다.
# ==============================
# 2번째 변수: Age
# IQR은 12.0 이다.
# lower bound 값은 13.0 이다.
# upper bound 값은 61.0 이다.
# 총 이상치 개수는 0 이다.
# ==============================
# 3번째 변수: CityTier
# IQR은 2.0 이다.
# lower bound 값은 -2.0 이다.
# upper bound 값은 6.0 이다.
# 총 이상치 개수는 0 이다.
# ==============================
# 4번째 변수: DurationOfPitch
# IQR은 10.0 이다.
# lower bound 값은 -6.0 이다.
# upper bound 값은 34.0 이다.
# 총 이상치 개수는 44 이다.
# ==============================
# 5번째 변수: NumberOfPersonVisiting
# IQR은 1.0 이다.
# lower bound 값은 0.5 이다.
# upper bound 값은 4.5 이다.
# 총 이상치 개수는 1 이다.
# ==============================
# 6번째 변수: NumberOfFollowups
# IQR은 1.0 이다.
# lower bound 값은 1.5 이다.
# upper bound 값은 5.5 이다.
# 총 이상치 개수는 120 이다.
# ==============================
# 7번째 변수: PreferredPropertyStar
# IQR은 1.0 이다.
# lower bound 값은 1.5 이다.
# upper bound 값은 5.5 이다.
# 총 이상치 개수는 0 이다.
# ==============================
# 8번째 변수: NumberOfTrips
# IQR은 2.0 이다.
# lower bound 값은 -1.0 이다.
# upper bound 값은 7.0 이다.
# 총 이상치 개수는 38 이다.
# ==============================
# 9번째 변수: Passport
# IQR은 1.0 이다.
# lower bound 값은 -1.5 이다.
# upper bound 값은 2.5 이다.
# 총 이상치 개수는 0 이다.
# ==============================
# 10번째 변수: PitchSatisfactionScore
# IQR은 2.0 이다.
# lower bound 값은 -1.0 이다.
# upper bound 값은 7.0 이다.
# 총 이상치 개수는 0 이다.
# ==============================
# 11번째 변수: OwnCar
# IQR은 1.0 이다.
# lower bound 값은 -1.5 이다.
# upper bound 값은 2.5 이다.
# 총 이상치 개수는 0 이다.
# ==============================
# 12번째 변수: NumberOfChildrenVisiting
# IQR은 1.0 이다.
# lower bound 값은 -0.5 이다.
# upper bound 값은 3.5 이다.
# 총 이상치 개수는 0 이다.
# ==============================
# 13번째 변수: MonthlyIncome
# IQR은 4889.0 이다.
# lower bound 값은 13222.5 이다.
# upper bound 값은 32778.5 이다.
# 총 이상치 개수는 144 이다.
# ==============================
# 14번째 변수: ProdTaken
# IQR은 0.0 이다.
# lower bound 값은 0.0 이다.
# upper bound 값은 0.0 이다.
# 총 이상치 개수는 381 이다.

# %%
# DurationOfPitch : 영업 사원이 고객에게 제공하는 프레젠테이션 기간 (44개)

sns.boxplot(train_df['DurationOfPitch'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(train_df['DurationOfPitch'].mean())
print(train_df['DurationOfPitch'].median())
# Out:
# 15.451928020565553
# 14.0

# %%
# NumberOfPersonVisiting : 고객과 함께 여행을 계획 중인 총 인원 (1개)

sns.boxplot(train_df['NumberOfPersonVisiting'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# NumberOfFollowups : 영업 사원의 프레젠테이션 후 이루어진 후속 조치 수 (120개)

sns.boxplot(train_df['NumberOfFollowups'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# NumberOfTrips : 평균 연간 여행 횟수 (38개)

sns.boxplot(train_df['NumberOfTrips'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# DurationOfPitch, NumberOfPersonVisiting, NumberOfFollowups, NumberOfTrips 변수에서 이상치는 충분히 가능한 값이라 생각되어 삭제하거나 대체하지 않음

# %%
# MonthlyIncome : 월 급여 (144) 

sns.boxplot(train_df['MonthlyIncome'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
train_df['MonthlyIncome'].describe()
# Out:
# count     1945.000000
# mean     23624.108895
# std       5508.368323
# min       1000.000000
# 25%      20556.000000
# 50%      22642.000000
# 75%      25445.000000
# max      98678.000000
# Name: MonthlyIncome, dtype: float64

# %%
# MonthlyIncome > 50000 인 행 삭제

idx = train_df[train_df['MonthlyIncome'] > 50000].index
train_df.drop(idx, inplace=True)

# %%
idx
# Out:
# Int64Index([604, 1338], dtype='int64')

# %%
train_df.select_dtypes(exclude=['object']).columns
# Out:
# Index(['id', 'Age', 'CityTier', 'DurationOfPitch', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'PreferredPropertyStar', 'NumberOfTrips',
#        'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'MonthlyIncome', 'ProdTaken'],
#       dtype='object')

# %%
train_df.dtypes
# Out:
# id                            int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# ProdTaken                     int64
# dtype: object

# %%
new_df = train_df[['Age', 'CityTier', 'DurationOfPitch', 'NumberOfPersonVisiting','NumberOfFollowups', 'PreferredPropertyStar', 'NumberOfTrips','Passport', 'PitchSatisfactionScore', 'OwnCar', 'NumberOfChildrenVisiting', 'ProdTaken']]

plt.figure(figsize=(15,10))
plt.xticks(rotation=45)
sns.boxplot(data=new_df)

# %%
sns.boxplot(data=train_df['MonthlyIncome'])

# %%
train_df.to_csv('/content/drive/MyDrive/DACON_BASIC/eda.csv')

# %% [markdown]
# ## 3. 데이터의 개별 속성값 관찰

# %% [markdown]
# #### 3-1. target 값 확인
# ProdTaken : 여행 패키지 신청 여부 (0: 신청 안 함, 1: 신청함)

# %%
sns.countplot(train_df['ProdTaken'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## 4. 속성 간의 관계 -> 패턴 발견 (상관관계, 시각화 등)

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_df.corr(), annot=True)

# %% [markdown]
# Age와 MonthlyIncome, NumberOfPersonVisiting과 NumberOfPersonVisiting 간의 상관관계가 높게 나타남

# %% [markdown]
# ## 5. 범주형 변수 변환

# %%
train_df.dtypes
# Out:
# id                            int64
# Age                         float64
# TypeofContact                object
# CityTier                      int64
# DurationOfPitch             float64
# Occupation                   object
# Gender                       object
# NumberOfPersonVisiting        int64
# NumberOfFollowups           float64
# ProductPitched               object
# PreferredPropertyStar       float64
# MaritalStatus                object
# NumberOfTrips               float64
# Passport                      int64
# PitchSatisfactionScore        int64
# OwnCar                        int64
# NumberOfChildrenVisiting    float64
# Designation                  object
# MonthlyIncome               float64
# ProdTaken                     int64
# dtype: object

# %%
train_df = pd.get_dummies(train_df,columns = ['TypeofContact', 'Occupation', 'Gender', 'ProductPitched', 'MaritalStatus', 'Designation'])

# %%
train_df
# Out:
#         id   Age  CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# 0        1  28.0         1             10.0                       3
# 1        2  34.0         3             14.0                       2
# 2        3  45.0         1             14.0                       2
# 3        4  29.0         1              7.0                       3
# 4        5  42.0         3              6.0                       2
# ...    ...   ...       ...              ...                     ...
# 1950  1951  28.0         1             10.0                       3
# 1951  1952  41.0         3              8.0                       3
# 1952  1953  38.0         3             28.0                       3
# 1953  1954  28.0         3             30.0                       3
# 1954  1955  22.0         1              9.0                       2
#
#       NumberOfFollowups  PreferredPropertyStar  NumberOfTrips  Passport  \
# 0                   4.0                    3.0            3.0         0
# 1                   4.0                    4.0            1.0         1
# 2                   3.0                    4.0            2.0         0
# 3                   5.0                    4.0            3.0         0
# 4                   3.0                    3.0            2.0         0
# ...                 ...                    ...            ...       ...
# 1950                5.0                    3.0            2.0         0
# 1951                3.0                    5.0            1.0         0
# 1952                4.0                    3.0            7.0         0
# 1953                5.0                    3.0            3.0         0
# 1954                4.0                    3.0            1.0         1
#
#       PitchSatisfactionScore  ...  ProductPitched_Super Deluxe  \
# 0                          1  ...                            0
# 1                          5  ...                            0
# 2                          4  ...                            0
# 3                          4  ...                            0
# 4                          3  ...                            0
# ...                      ...  ...                          ...
# 1950                       1  ...                            0
# 1951                       5  ...                            1
# 1952                       2  ...                            0
# 1953                       1  ...                            0
# 1954                       3  ...                            0
#
#       MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single  \
# 0                          0                      1                     0
# 1                          0                      0                     1
# 2                          0                      1                     0
# 3                          0                      1                     0
# 4                          1                      0                     0
# ...                      ...                    ...                   ...
# 1950                       0                      0                     1
# 1951                       1                      0                     0
# 1952                       1                      0                     0
# 1953                       0                      1                     0
# 1954                       1                      0                     0
#
#       MaritalStatus_Unmarried  Designation_AVP  Designation_Executive  \
# 0                           0                0                      1
# 1                           0                0                      0
# 2                           0                0                      0
# 3                           0                0                      1
# 4                           0                0                      0
# ...                       ...              ...                    ...
# 1950                        0                0                      1
# 1951                        0                1                      0
# 1952                        0                0                      1
# 1953                        0                0                      0
# 1954                        0                0                      1
#
#       Designation_Manager  Designation_Senior Manager  Designation_VP
# 0                       0                           0               0
# 1                       1                           0               0
# 2                       1                           0               0
# 3                       0                           0               0
# 4                       1                           0               0
# ...                   ...                         ...             ...
# 1950                    0                           0               0
# 1951                    0                           0               0
# 1952                    0                           0               0
# 1953                    1                           0               0
# 1954                    0                           0               0
#
# [1943 rows x 36 columns]

# %% [markdown]
# ## 6. 모델 적용

# %% [markdown]
# ### 6-1. 랜덤포레스트 (RandomForestClassifier)

# %%
from sklearn.ensemble import RandomForestClassifier

# 모델 선언
model = RandomForestClassifier(n_estimators=5, random_state=0)

# %%
# 학습에 사용할 정보와 예측하고자 하는 정보를 분리합니다.
x = train_df.drop(columns=['ProdTaken'])
y = train_df[['ProdTaken']]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.40, random_state=42)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (1165, 35) (1165, 1)

# %%
print(x_test.shape, y_test.shape)
# Out:
# (778, 35) (778, 1)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=5,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
pred_test_y = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(pred_test_y, y_test)
# Out:
# 0.19023136246786632

# %% [markdown]
# ### 6-2. XGBClassifier

# %%
from xgboost import XGBClassifier
from xgboost import plot_importance

# 객체 생성
model = XGBClassifier(learning_rate=0.1)

# %%
xgb_model = model.fit(x_train, y_train)
xgb_model
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
# 예측하기
pred_test_y = model.predict(x_test)

# 특성 중요도 시각화
fig, ax = plt.subplots(figsize=(10,12))
plot_importance(xgb_model, ax=ax)

# %% [markdown]
# ### 6-3. LGBMClassifier

# %%
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score

lgbm = LGBMClassifier(n_estimators=200)

params = {'max_depth': [10, 15, 20],
          'min_child_samples': [20, 40, 60],
          'subsample': [0.8, 1]}

grid = GridSearchCV(lgbm, param_grid=params)
grid.fit(x_train, y_train, early_stopping_rounds=100, eval_metric='auc',
         eval_set=[(x_train, y_train), (x_test, y_test)])

print("최적 파라미터: ", grid.best_params_)
lgbm_roc_score = roc_auc_score(y_test, grid.predict_proba(x_test)[:, 1], average='macro')
print("ROC AUC: {0:.4f}".format(lgbm_roc_score))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [104]	valid_0's auc: 0.96106	valid_0's binary_logloss: 0.206166	valid_1's auc: 0.782211	valid_1's binary_logloss: 0.414594
# [105]	valid_0's auc: 0.96127	valid_0's binary_logloss: 0.205444	valid_1's auc: 0.783024	valid_1's binary_logloss: 0.414334
# [106]	valid_0's auc: 0.961427	valid_0's binary_logloss: 0.204736	valid_1's auc: 0.783827	valid_1's binary_logloss: 0.413464
# [107]	valid_0's auc: 0.96169	valid_0's binary_logloss: 0.203691	valid_1's auc: 0.784121	valid_1's binary_logloss: 0.413466
# [108]	valid_0's auc: 0.961977	valid_0's binary_logloss: 0.202732	valid_1's auc: 0.783857	valid_1's binary_logloss: 0.413927
# [109]	valid_0's auc: 0.962822	valid_0's binary_logloss: 0.201315	valid_1's auc: 0.784457	valid_1's binary_logloss: 0.414175
# [110]	valid_0's auc: 0.962775	valid_0's binary_logloss: 0.200639	valid_1's auc: 0.784528	valid_1's binary_logloss: 0.414419
# [111]	valid_0's auc: 0.962985	valid_0's binary_logloss: 0.199888	valid_1's auc: 0.785056	valid_1's binary_logloss: 0.414558
# [112]	valid_0's auc: 0.963343	valid_0's binary_logloss: 0.198906	valid_1's auc: 0.785056	valid_1's binary_logloss: 0.415015
# [113]	valid_0's auc: 0.96363	valid_0's binary_logloss: 0.197993	valid_1's auc: 0.784355	valid_1's binary_logloss: 0.415316
# [114]	valid_0's auc: 0.963496	valid_0's binary_logloss: 0.197415	valid_1's auc: 0.783288	valid_1's binary_logloss: 0.416498
# [115]	valid_0's auc: 0.964169	valid_0's binary_logloss: 0.196163	valid_1's auc: 0.78402	valid_1's binary_logloss: 0.416369
# [116]	valid_0's auc: 0.964528	valid_0's binary_logloss: 0.195251	valid_1's auc: 0.784711	valid_1's binary_logloss: 0.416212
# [117]	valid_0's auc: 0.964747	valid_0's binary_logloss: 0.194419	valid_1's auc: 0.78596	valid_1's binary_logloss: 0.415507
# [118]	valid_0's auc: 0.965192	valid_0's binary_logloss: 0.193706	valid_1's auc: 0.785381	valid_1's binary_logloss: 0.415812
# [119]	valid_0's auc: 0.965082	valid_0's binary_logloss: 0.192986	valid_1's auc: 0.785849	valid_1's binary_logloss: 0.415777
# [64]	training's auc: 0.979574	training's binary_logloss: 0.212709	valid_1's auc: 0.792666	valid_1's binary_logloss: 0.402319
# [65]	training's auc: 0.980363	training's binary_logloss: 0.210765	valid_1's auc: 0.79225	valid_1's binary_logloss: 0.402274
# [66]	training's auc: 0.980974	training's binary_logloss: 0.209237	valid_1's auc: 0.793347	valid_1's binary_logloss: 0.401553
# [67]	training's auc: 0.98149	training's binary_logloss: 0.207856	valid_1's auc: 0.793225	valid_1's binary_logloss: 0.401683
# [68]	training's auc: 0.982183	training's binary_logloss: 0.206182	valid_1's auc: 0.79357	valid_1's binary_logloss: 0.401654
# [69]	training's auc: 0.982904	training's binary_logloss: 0.204543	valid_1's auc: 0.793327	valid_1's binary_logloss: 0.401934
# [70]	training's auc: 0.983248	training's binary_logloss: 0.203292	valid_1's auc: 0.794302	valid_1's binary_logloss: 0.40131
# [71]	training's auc: 0.984084	training's binary_logloss: 0.201231	valid_1's auc: 0.795664	valid_1's binary_logloss: 0.399902
# [72]	training's auc: 0.984944	training's binary_logloss: 0.199651	valid_1's auc: 0.795918	valid_1's binary_logloss: 0.399763
# [73]	training's auc: 0.985507	training's binary_logloss: 0.198113	valid_1's auc: 0.795562	valid_1's binary_logloss: 0.400365
# [74]	training's auc: 0.98588	training's binary_logloss: 0.197176	valid_1's auc: 0.795531	valid_1's binary_logloss: 0.400261
# [75]	training's auc: 0.986697	training's binary_logloss: 0.195023	valid_1's auc: 0.796476	valid_1's binary_logloss: 0.399713
# [76]	training's auc: 0.98759	training's binary_logloss: 0.19265	valid_1's auc: 0.796629	valid_1's binary_logloss: 0.399928
# [77]	training's auc: 0.987924	training's binary_logloss: 0.191333	valid_1's auc: 0.797289	valid_1's binary_logloss: 0.399821
# [78]	training's auc: 0.988173	training's binary_logloss: 0.189651	valid_1's auc: 0.798153	valid_1's binary_logloss: 0.399294
# [79]	training's auc: 0.988951	training's binary_logloss: 0.187947	valid_1's auc: 0.798366	valid_1's binary_logloss: 0.39935
# [80]	training's auc: 0.989462	training's binary_logloss: 0.186135	valid_1's auc: 0.798102	valid_1's binary_logloss: 0.399935
# [81]	training's auc: 0.989825	training's binary_logloss: 0.184482	valid_1's auc: 0.799149	valid_1's binary_logloss: 0.399003
# [82]	training's auc: 0.990403	training's binary_logloss: 0.182826	valid_1's auc: 0.800002	valid_1's binary_logloss: 0.398387
# [83]	training's auc: 0.990843	training's binary_logloss: 0.181236	valid_1's auc: 0.800632	valid_1's binary_logloss: 0.39824
# [84]	training's auc: 0.991029	training's binary_logloss: 0.179893	valid_1's auc: 0.800287	valid_1's binary_logloss: 0.399035
# [85]	training's auc: 0.991516	training's binary_logloss: 0.178662	valid_1's auc: 0.799199	valid_1's binary_logloss: 0.39988
# [86]	training's auc: 0.991784	training's binary_logloss: 0.177519	valid_1's auc: 0.799433	valid_1's binary_logloss: 0.399958
# [87]	training's auc: 0.992042	training's binary_logloss: 0.175951	valid_1's auc: 0.800784	valid_1's binary_logloss: 0.398903
# [113]	training's auc: 0.997827	training's binary_logloss: 0.140349	valid_1's auc: 0.801333	valid_1's binary_logloss: 0.405147
# [114]	training's auc: 0.997951	training's binary_logloss: 0.139109	valid_1's auc: 0.801841	valid_1's binary_logloss: 0.405084
# [115]	training's auc: 0.998046	training's binary_logloss: 0.137938	valid_1's auc: 0.799779	valid_1's binary_logloss: 0.406867
# [116]	training's auc: 0.998237	training's binary_logloss: 0.136707	valid_1's auc: 0.799331	valid_1's binary_logloss: 0.407365
# [117]	training's auc: 0.998309	training's binary_logloss: 0.135615	valid_1's auc: 0.800073	valid_1's binary_logloss: 0.407451
# [118]	training's auc: 0.998362	training's binary_logloss: 0.134688	valid_1's auc: 0.799616	valid_1's binary_logloss: 0.408065
# [119]	training's auc: 0.998486	training's binary_logloss: 0.133498	valid_1's auc: 0.800368	valid_1's binary_logloss: 0.408016
# [120]	training's auc: 0.998572	training's binary_logloss: 0.132479	valid_1's auc: 0.80051	valid_1's binary_logloss: 0.407558
# [121]	training's auc: 0.998653	training's binary_logloss: 0.13134	valid_1's auc: 0.800083	valid_1's binary_logloss: 0.408253
# [122]	training's auc: 0.998758	training's binary_logloss: 0.130173	valid_1's auc: 0.800856	valid_1's binary_logloss: 0.407664
# [123]	training's auc: 0.998877	training's binary_logloss: 0.129301	valid_1's auc: 0.80053	valid_1's binary_logloss: 0.407872
# [124]	training's auc: 0.998897	training's binary_logloss: 0.128101	valid_1's auc: 0.80052	valid_1's binary_logloss: 0.408164
# [125]	training's auc: 0.998911	training's binary_logloss: 0.127206	valid_1's auc: 0.800835	valid_1's binary_logloss: 0.408396
# [126]	training's auc: 0.999016	training's binary_logloss: 0.126378	valid_1's auc: 0.800866	valid_1's binary_logloss: 0.408471
# [127]	training's auc: 0.999078	training's binary_logloss: 0.125538	valid_1's auc: 0.800195	valid_1's binary_logloss: 0.409354
# [128]	training's auc: 0.999126	training's binary_logloss: 0.124739	valid_1's auc: 0.799972	valid_1's binary_logloss: 0.409646
# [129]	training's auc: 0.999174	training's binary_logloss: 0.123637	valid_1's auc: 0.800784	valid_1's binary_logloss: 0.409042
# [130]	training's auc: 0.999193	training's binary_logloss: 0.122881	valid_1's auc: 0.800236	valid_1's binary_logloss: 0.409984
# [131]	training's auc: 0.999217	training's binary_logloss: 0.121902	valid_1's auc: 0.800053	valid_1's binary_logloss: 0.410676
# [132]	training's auc: 0.999245	training's binary_logloss: 0.121274	valid_1's auc: 0.799697	valid_1's binary_logloss: 0.411103
# [133]	training's auc: 0.999288	training's binary_logloss: 0.120393	valid_1's auc: 0.799301	valid_1's binary_logloss: 0.411684
# [134]	training's auc: 0.999384	training's binary_logloss: 0.119376	valid_1's auc: 0.799077	valid_1's binary_logloss: 0.412372
# [135]	training's auc: 0.999403	training's binary_logloss: 0.118526	valid_1's auc: 0.798762	valid_1's binary_logloss: 0.412743
# [136]	training's auc: 0.999465	training's binary_logloss: 0.11763	valid_1's auc: 0.799037	valid_1's binary_logloss: 0.412536
# [137]	training's auc: 0.999489	training's binary_logloss: 0.116715	valid_1's auc: 0.797279	valid_1's binary_logloss: 0.414431
# [138]	training's auc: 0.999479	training's binary_logloss: 0.116115	valid_1's auc: 0.796812	valid_1's binary_logloss: 0.415058
# [139]	training's auc: 0.999475	training's binary_logloss: 0.115233	valid_1's auc: 0.797045	valid_1's binary_logloss: 0.415348
# [140]	training's auc: 0.999537	training's binary_logloss: 0.113687	valid_1's auc: 0.797391	valid_1's binary_logloss: 0.415929
# [141]	training's auc: 0.99957	training's binary_logloss: 0.112842	valid_1's auc: 0.797299	valid_1's binary_logloss: 0.416589
# [142]	training's auc: 0.999608	training's binary_logloss: 0.111919	valid_1's auc: 0.797807	valid_1's binary_logloss: 0.416382
# [143]	training's auc: 0.999666	training's binary_logloss: 0.111225	valid_1's auc: 0.797025	valid_1's binary_logloss: 0.417578
# [144]	training's auc: 0.999694	training's binary_logloss: 0.110381	valid_1's auc: 0.796476	valid_1's binary_logloss: 0.418283
# [145]	training's auc: 0.999718	training's binary_logloss: 0.109394	valid_1's auc: 0.79734	valid_1's binary_logloss: 0.417664
# [146]	training's auc: 0.999752	training's binary_logloss: 0.108328	valid_1's auc: 0.797482	valid_1's binary_logloss: 0.417355
# [147]	training's auc: 0.999742	training's binary_logloss: 0.107255	valid_1's auc: 0.796578	valid_1's binary_logloss: 0.418778
# [148]	training's auc: 0.999761	training's binary_logloss: 0.106414	valid_1's auc: 0.796578	valid_1's binary_logloss: 0.419358
# [149]	training's auc: 0.999771	training's binary_logloss: 0.105671	valid_1's auc: 0.797238	valid_1's binary_logloss: 0.419096
# [150]	training's auc: 0.999766	training's binary_logloss: 0.104762	valid_1's auc: 0.797604	valid_1's binary_logloss: 0.419422
# [151]	training's auc: 0.999795	training's binary_logloss: 0.104045	valid_1's auc: 0.79734	valid_1's binary_logloss: 0.420147
# [152]	training's auc: 0.999804	training's binary_logloss: 0.103511	valid_1's auc: 0.797299	valid_1's binary_logloss: 0.420363
# [153]	training's auc: 0.999838	training's binary_logloss: 0.102824	valid_1's auc: 0.797157	valid_1's binary_logloss: 0.420359
# [154]	training's auc: 0.999838	training's binary_logloss: 0.102071	valid_1's auc: 0.796659	valid_1's binary_logloss: 0.421192
# [155]	training's auc: 0.999852	training's binary_logloss: 0.101408	valid_1's auc: 0.796487	valid_1's binary_logloss: 0.421732
# [156]	training's auc: 0.999871	training's binary_logloss: 0.100467	valid_1's auc: 0.797279	valid_1's binary_logloss: 0.421217
# [157]	training's auc: 0.999881	training's binary_logloss: 0.0996203	valid_1's auc: 0.797838	valid_1's binary_logloss: 0.421219
# [158]	training's auc: 0.999885	training's binary_logloss: 0.0987881	valid_1's auc: 0.798813	valid_1's binary_logloss: 0.421122
# [159]	training's auc: 0.999909	training's binary_logloss: 0.0982379	valid_1's auc: 0.799128	valid_1's binary_logloss: 0.421375
# [160]	training's auc: 0.999904	training's binary_logloss: 0.0976073	valid_1's auc: 0.798458	valid_1's binary_logloss: 0.42198
# [161]	training's auc: 0.9999	training's binary_logloss: 0.0969653	valid_1's auc: 0.798498	valid_1's binary_logloss: 0.422313
# [162]	training's auc: 0.999904	training's binary_logloss: 0.0963181	valid_1's auc: 0.798163	valid_1's binary_logloss: 0.423143
# [163]	training's auc: 0.999924	training's binary_logloss: 0.0954214	valid_1's auc: 0.798072	valid_1's binary_logloss: 0.423425
# [164]	training's auc: 0.999919	training's binary_logloss: 0.0947485	valid_1's auc: 0.798143	valid_1's binary_logloss: 0.424116
# [165]	training's auc: 0.999928	training's binary_logloss: 0.0942951	valid_1's auc: 0.797614	valid_1's binary_logloss: 0.424673
# [166]	training's auc: 0.999928	training's binary_logloss: 0.0935528	valid_1's auc: 0.797442	valid_1's binary_logloss: 0.424842
# [167]	training's auc: 0.999933	training's binary_logloss: 0.0928191	valid_1's auc: 0.797624	valid_1's binary_logloss: 0.425211
# [168]	training's auc: 0.999933	training's binary_logloss: 0.0921359	valid_1's auc: 0.797289	valid_1's binary_logloss: 0.42595
# [169]	training's auc: 0.999943	training's binary_logloss: 0.0913826	valid_1's auc: 0.796669	valid_1's binary_logloss: 0.426279
# [170]	training's auc: 0.999943	training's binary_logloss: 0.090809	valid_1's auc: 0.796375	valid_1's binary_logloss: 0.42732
# [171]	training's auc: 0.999952	training's binary_logloss: 0.0900897	valid_1's auc: 0.796243	valid_1's binary_logloss: 0.427469
# [172]	training's auc: 0.999943	training's binary_logloss: 0.0895712	valid_1's auc: 0.795958	valid_1's binary_logloss: 0.428335
# [173]	training's auc: 0.999952	training's binary_logloss: 0.0889161	valid_1's auc: 0.796019	valid_1's binary_logloss: 0.428731
# [174]	training's auc: 0.999957	training's binary_logloss: 0.0883131	valid_1's auc: 0.795603	valid_1's binary_logloss: 0.429332
# [175]	training's auc: 0.999967	training's binary_logloss: 0.0877968	valid_1's auc: 0.794749	valid_1's binary_logloss: 0.430407
# [176]	training's auc: 0.999971	training's binary_logloss: 0.0873173	valid_1's auc: 0.793997	valid_1's binary_logloss: 0.431808
# [177]	training's auc: 0.999976	training's binary_logloss: 0.0866104	valid_1's auc: 0.794211	valid_1's binary_logloss: 0.431634
# [178]	training's auc: 0.999981	training's binary_logloss: 0.0860415	valid_1's auc: 0.794708	valid_1's binary_logloss: 0.431526
# [179]	training's auc: 0.999981	training's binary_logloss: 0.0854316	valid_1's auc: 0.794231	valid_1's binary_logloss: 0.432139
# [180]	training's auc: 0.999981	training's binary_logloss: 0.0846801	valid_1's auc: 0.794526	valid_1's binary_logloss: 0.432355
# [181]	training's auc: 0.999981	training's binary_logloss: 0.0840846	valid_1's auc: 0.794353	valid_1's binary_logloss: 0.432446
# [182]	training's auc: 0.999981	training's binary_logloss: 0.0835784	valid_1's auc: 0.793957	valid_1's binary_logloss: 0.43306
# [183]	training's auc: 0.999981	training's binary_logloss: 0.0830561	valid_1's auc: 0.793184	valid_1's binary_logloss: 0.433861
# 최적 파라미터:  {'max_depth': 10, 'min_child_samples': 60, 'subsample': 0.8}
# ROC AUC: 0.8006

# %%
lgbm = LGBMClassifier(max_depth=10, min_child_samples=60, subsample=0.8)

evals = [(x_test, y_test)]
lgbm.fit(x_train, y_train, early_stopping_rounds=100, eval_metric='auc',
         eval_set=evals, verbose=True)

score = roc_auc_score(y_test, grid.predict_proba(x_test)[:, 1], average='macro')
print("ROC AUC: {0:.4f}".format(score))
# Out:
# [1]	valid_0's auc: 0.731338	valid_0's binary_logloss: 0.489827
# [2]	valid_0's auc: 0.718668	valid_0's binary_logloss: 0.478778
# [3]	valid_0's auc: 0.72199	valid_0's binary_logloss: 0.469994
# [4]	valid_0's auc: 0.721914	valid_0's binary_logloss: 0.460804
# [5]	valid_0's auc: 0.725668	valid_0's binary_logloss: 0.455896
# [6]	valid_0's auc: 0.73086	valid_0's binary_logloss: 0.450309
# [7]	valid_0's auc: 0.734985	valid_0's binary_logloss: 0.446355
# [8]	valid_0's auc: 0.737957	valid_0's binary_logloss: 0.441886
# [9]	valid_0's auc: 0.744308	valid_0's binary_logloss: 0.438135
# [10]	valid_0's auc: 0.740807	valid_0's binary_logloss: 0.437589
# [11]	valid_0's auc: 0.743469	valid_0's binary_logloss: 0.435069
# [12]	valid_0's auc: 0.742885	valid_0's binary_logloss: 0.434261
# [13]	valid_0's auc: 0.747996	valid_0's binary_logloss: 0.431078
# [14]	valid_0's auc: 0.746645	valid_0's binary_logloss: 0.430669
# [15]	valid_0's auc: 0.75206	valid_0's binary_logloss: 0.427937
# [16]	valid_0's auc: 0.754605	valid_0's binary_logloss: 0.425695
# [17]	valid_0's auc: 0.758883	valid_0's binary_logloss: 0.42341
# [18]	valid_0's auc: 0.761819	valid_0's binary_logloss: 0.420794
# [19]	valid_0's auc: 0.765172	valid_0's binary_logloss: 0.418412
# [20]	valid_0's auc: 0.769602	valid_0's binary_logloss: 0.41612
# [21]	valid_0's auc: 0.769511	valid_0's binary_logloss: 0.415876
# [22]	valid_0's auc: 0.7695	valid_0's binary_logloss: 0.415024
# [23]	valid_0's auc: 0.76881	valid_0's binary_logloss: 0.415182
# [24]	valid_0's auc: 0.770455	valid_0's binary_logloss: 0.414368
# [25]	valid_0's auc: 0.772538	valid_0's binary_logloss: 0.413037
# [26]	valid_0's auc: 0.772701	valid_0's binary_logloss: 0.41279
# [27]	valid_0's auc: 0.772528	valid_0's binary_logloss: 0.412556
# [28]	valid_0's auc: 0.776298	valid_0's binary_logloss: 0.410075
# [29]	valid_0's auc: 0.776857	valid_0's binary_logloss: 0.40995
# [30]	valid_0's auc: 0.777995	valid_0's binary_logloss: 0.409387
# [31]	valid_0's auc: 0.779133	valid_0's binary_logloss: 0.408562
# [32]	valid_0's auc: 0.779508	valid_0's binary_logloss: 0.408588
# [33]	valid_0's auc: 0.779011	valid_0's binary_logloss: 0.40863
# [34]	valid_0's auc: 0.780392	valid_0's binary_logloss: 0.40753
# [35]	valid_0's auc: 0.780128	valid_0's binary_logloss: 0.407875
# [36]	valid_0's auc: 0.782485	valid_0's binary_logloss: 0.406893
# [37]	valid_0's auc: 0.785645	valid_0's binary_logloss: 0.404959
# [38]	valid_0's auc: 0.786743	valid_0's binary_logloss: 0.404227
# [39]	valid_0's auc: 0.785615	valid_0's binary_logloss: 0.404624
# [40]	valid_0's auc: 0.787972	valid_0's binary_logloss: 0.403063
# [41]	valid_0's auc: 0.786824	valid_0's binary_logloss: 0.403414
# [42]	valid_0's auc: 0.788947	valid_0's binary_logloss: 0.402051
# [43]	valid_0's auc: 0.789638	valid_0's binary_logloss: 0.401672
# [44]	valid_0's auc: 0.787362	valid_0's binary_logloss: 0.403215
# [45]	valid_0's auc: 0.789242	valid_0's binary_logloss: 0.402516
# [46]	valid_0's auc: 0.788998	valid_0's binary_logloss: 0.403029
# [47]	valid_0's auc: 0.7885	valid_0's binary_logloss: 0.403485
# [48]	valid_0's auc: 0.786733	valid_0's binary_logloss: 0.404745
# [49]	valid_0's auc: 0.78658	valid_0's binary_logloss: 0.404895
# [50]	valid_0's auc: 0.787352	valid_0's binary_logloss: 0.404631
# [51]	valid_0's auc: 0.788511	valid_0's binary_logloss: 0.403856
# [52]	valid_0's auc: 0.789425	valid_0's binary_logloss: 0.403617
# [53]	valid_0's auc: 0.789141	valid_0's binary_logloss: 0.403206
# [54]	valid_0's auc: 0.789201	valid_0's binary_logloss: 0.403239
# [55]	valid_0's auc: 0.788602	valid_0's binary_logloss: 0.403792
# [56]	valid_0's auc: 0.789395	valid_0's binary_logloss: 0.402774
# [57]	valid_0's auc: 0.792219	valid_0's binary_logloss: 0.401119
# [58]	valid_0's auc: 0.791051	valid_0's binary_logloss: 0.401867
# [59]	valid_0's auc: 0.790726	valid_0's binary_logloss: 0.401974
# [60]	valid_0's auc: 0.790146	valid_0's binary_logloss: 0.402695
# [61]	valid_0's auc: 0.791274	valid_0's binary_logloss: 0.402281
# [62]	valid_0's auc: 0.791274	valid_0's binary_logloss: 0.402806
# [63]	valid_0's auc: 0.792057	valid_0's binary_logloss: 0.4027
# [64]	valid_0's auc: 0.792666	valid_0's binary_logloss: 0.402319
# [65]	valid_0's auc: 0.79225	valid_0's binary_logloss: 0.402274
# [66]	valid_0's auc: 0.793347	valid_0's binary_logloss: 0.401553
# [67]	valid_0's auc: 0.793225	valid_0's binary_logloss: 0.401683
# [68]	valid_0's auc: 0.79357	valid_0's binary_logloss: 0.401654
# [69]	valid_0's auc: 0.793327	valid_0's binary_logloss: 0.401934
# [70]	valid_0's auc: 0.794302	valid_0's binary_logloss: 0.40131
# [71]	valid_0's auc: 0.795664	valid_0's binary_logloss: 0.399902
# [72]	valid_0's auc: 0.795918	valid_0's binary_logloss: 0.399763
# [73]	valid_0's auc: 0.795562	valid_0's binary_logloss: 0.400365
# [74]	valid_0's auc: 0.795531	valid_0's binary_logloss: 0.400261
# [75]	valid_0's auc: 0.796476	valid_0's binary_logloss: 0.399713
# [76]	valid_0's auc: 0.796629	valid_0's binary_logloss: 0.399928
# [77]	valid_0's auc: 0.797289	valid_0's binary_logloss: 0.399821
# [78]	valid_0's auc: 0.798153	valid_0's binary_logloss: 0.399294
# [79]	valid_0's auc: 0.798366	valid_0's binary_logloss: 0.39935
# [80]	valid_0's auc: 0.798102	valid_0's binary_logloss: 0.399935
# [81]	valid_0's auc: 0.799149	valid_0's binary_logloss: 0.399003
# [82]	valid_0's auc: 0.800002	valid_0's binary_logloss: 0.398387
# [83]	valid_0's auc: 0.800632	valid_0's binary_logloss: 0.39824
# [84]	valid_0's auc: 0.800287	valid_0's binary_logloss: 0.399035
# [85]	valid_0's auc: 0.799199	valid_0's binary_logloss: 0.39988
# [86]	valid_0's auc: 0.799433	valid_0's binary_logloss: 0.399958
# [87]	valid_0's auc: 0.800784	valid_0's binary_logloss: 0.398903
# [88]	valid_0's auc: 0.800541	valid_0's binary_logloss: 0.399501
# [89]	valid_0's auc: 0.801191	valid_0's binary_logloss: 0.399174
# [90]	valid_0's auc: 0.800073	valid_0's binary_logloss: 0.400283
# [91]	valid_0's auc: 0.799789	valid_0's binary_logloss: 0.401086
# [92]	valid_0's auc: 0.799352	valid_0's binary_logloss: 0.401616
# [93]	valid_0's auc: 0.800053	valid_0's binary_logloss: 0.40102
# [94]	valid_0's auc: 0.801353	valid_0's binary_logloss: 0.40016
# [95]	valid_0's auc: 0.800957	valid_0's binary_logloss: 0.400862
# [96]	valid_0's auc: 0.800073	valid_0's binary_logloss: 0.401988
# [97]	valid_0's auc: 0.799596	valid_0's binary_logloss: 0.402703
# [98]	valid_0's auc: 0.799707	valid_0's binary_logloss: 0.402539
# [99]	valid_0's auc: 0.800114	valid_0's binary_logloss: 0.402693
# [100]	valid_0's auc: 0.801424	valid_0's binary_logloss: 0.402054
# ROC AUC: 0.8006

# %% [markdown]
# - https://libertegrace.tistory.com/entry/Classification-4-%EC%95%99%EC%83%81%EB%B8%94-%ED%95%99%EC%8A%B5Ensemble-Learning-Boosting3-XGBoost
# - https://greeksharifa.github.io/machine_learning/2019/12/09/Light-GBM/
# - https://teddylee777.github.io/scikit-learn/grid-search-%EB%A1%9C-hyperparameter%EC%B5%9C%EC%A0%81%ED%99%94
# - https://kimdingko-world.tistory.com/175
# - https://steadiness-193.tistory.com/268

# %% [markdown]
# ### 6-4. SVM

# %%
# https://liveyourit.tistory.com/62

# %% [markdown]
# 1. 군집 (중간발표때 만든게 있죠.. 이거 이어서?)
# - k개수대로 각자 만들고
# - 전처리 + EDA : 주영
# - 모델 : 재원
#
# 2. 데이콘
# - 전처리 : 호경
# - EDA : 나경
# - model : 민영
#
# 3. 모델 각자 정해서

# %% [markdown]
# **1. 모델별 성능 비교**
#   - logistic regression
#   - KNN (K-Nearest Neighbor)
#   - Naives Bayes
#   - Decision Tree Classifier
#   - SVM
#   - Ridge
#   - Random Forest Classifier
#   - XGBRegressor
#   - Ada Boost Classifier
#   - Gradient Boosting Classifier (GBM)
#   - Light Gradient Boosting (LGBM)
#   - CatBoost Classifier
#
# **2. 하이퍼파라미터 조정**
#   - randomsearch
#   - gridsearch
#   - Bayesian Optimization
#
# (https://velog.io/@crosstar1228/MLHyperparameter-tuning-%EA%B8%B0%EB%B2%95%EC%9D%98-3%EA%B0%80%EC%A7%80GridSearch-RandomSearch-Bayesian-Optimization)
